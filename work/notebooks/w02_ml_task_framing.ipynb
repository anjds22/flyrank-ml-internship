# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/anjds22/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I will frame this as a ranking problem. The goal is to rank content pages by their likelihood of needing a refresh so that an SEO team can review the highest-priority pages first. Ranking fits this problem because the main goal is prioritisation rather than only predicting a yes or no outcome.

# %%
import os, subprocess

if not os.path.isdir("flyrank-ml-internship-starter"):
    subprocess.run([
        "git", "clone", "--depth", "1",
        "https://github.com/flyrank-bih/flyrank-ml-internship-starter",
        "flyrank-ml-internship-starter"
    ], check=True)

os.chdir("flyrank-ml-internship-starter")

print("Working directory:", os.getcwd())
print("Dataset exists:", os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# Working directory: /content/flyrank-ml-internship-starter
# Dataset exists: True

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target is identifying pages that are showing signs of declining search performance. A proxy label can be created from observed changes in impressions over time, such as whether impressions decreased beyond a certain threshold. This uses measurable outcomes from the dataset rather than assuming the reason behind the decline.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# The success metric will be Precision@50. This measures how many of the top 50 recommended pages are actually pages showing decline. This metric matches the business decision because content teams usually have limited time and need the most useful pages surfaced first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# The unit of analysis is one content page. Each row represents one individual page and contains its search performance signals, content characteristics, and observed trend direction.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df[[
    "content_id",
    "impressions_90d",
    "avg_position",
    "ctr",
    "word_count",
    "trend_direction"
]].head()
# Out:
#              content_id  impressions_90d  avg_position   ctr  word_count  \
# 0  content_304f48230142             3803          10.6  0.76      3221.0
# 1  content_a1fb4e703a9e            15320          20.3  0.05      2481.0
# 2  content_9aa793d4d895            12581          36.5  0.09      3515.0
# 3  content_331d6c4de07b            11751           6.2  0.49         NaN
# 4  content_d99b7a2d90ca            19140          44.0  0.13      2803.0
#
#   trend_direction
# 0            down
# 1            down
# 2            down
# 3          stable
# 4            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule might only consider one factor, such as pages that have not been updated recently. However, search performance depends on multiple interacting signals, including impressions, rankings, CTR, and engagement. ML can combine these signals and identify patterns that are difficult to capture with a simple if-statement.

# %% [markdown]
# A fixed rule might only consider one factor, such as pages that have not been updated recently. However, search performance depends on multiple interacting signals, including impressions, rankings, CTR, and engagement. ML can combine these signals and identify patterns that are difficult to capture with a simple if-statement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
