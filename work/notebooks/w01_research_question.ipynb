# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/anjds22/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os, subprocess

if not os.path.isdir("flyrank-ml-internship"):
    subprocess.run([
        "git", "clone", "--depth", "1",
        "https://github.com/flyrank-bih/flyrank-ml-internship-starter",
        "flyrank-ml-internship"
    ], check=True)

os.chdir("flyrank-ml-internship")

print("Working directory:", os.getcwd())
print("Dataset exists:", os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# Working directory: /content/flyrank-ml-internship
# Dataset exists: True

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the Content Refresh Prediction lane because businesses need to know which pages should be updated first. Rather than reviewing every page manually, I want to identify pages that are most likely to be declining so teams can prioritise their work. This problem has a clear business decision and can be supported using the available search performance data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision is which pages should be reviewed for a content refresh. The action is that an SEO or content team updates the highest-priority pages first. A wrong recommendation could waste time updating healthy pages or miss pages that are losing traffic, reducing search visibility and business value.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains 30,000 content pages with 44 features. The correlation between search volume and impressions is close to zero, showing that search volume alone is not enough to explain page traffic. The dataset contains enough information to investigate which pages are likely to decline and require a refresh.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Correlation between search volume and impressions:",
      round(df["search_volume"].corr(df["impressions_90d"]), 3))
print("Median word count:",
      int(df["word_count"].median()))
# Out:
# Rows: 30000
# Columns: 44
# Correlation between search volume and impressions: 0.001
# Median word count: 2877

# %% [markdown]
# This project provides decision-support based on observed patterns in the data. It may identify relationships that help prioritise content reviews, but it does not prove causation or predict Google's algorithm. Any recommendations should be treated as guidance rather than certainty.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides decision-support based on observed patterns in the data. It may identify relationships that help prioritise content reviews, but it does not prove causation or predict Google's algorithm. Any recommendations should be treated as guidance rather than certainty.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
